# %% [markdown]
# # TODO
#
# - улучшить парсер (убрать пустые тексты)
# - убрать наны из текстов!!!!
# - выкинуть некириллицу
# - возьмем обученные эмбеддинги у Гали
# - tf-idf
#
# ## Метрики
# длина текста, tf-idf, лемматизированные тексты, максимальное и минимальное косинусное расстояние между парами слов (соседних и не соседних, если успеем посчитать), tf-idf взвешенное (умножать каждое слово на tf-idf этого слова для этого документа)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import matplotlib
# %matplotlib inline
import random
import warnings

df = pd.read_csv('data.csv', index_col='id')
df = df.sample(frac=1)
df.head()
# Out:
#                                                    text       group
# id
# 1949  ТАИНСТВЕННЫЕ МЕСТА РОССИИ - ЦЕРКОВЬ ВСЕХ СВЯТЫ...         ufo
# 159   Забавно, но Москва самый крупный «белый» город...    podkoren
# 675                                                 NaN  krishnaits
# 2847  КУДАХ НЕ ДОПОМОГ\n\n8 утра. в шизо-селе снова ...       kudah
# 446   Из «Повести временных лет» нам известно, что о...    podkoren

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.describe(include=[np.object])
# Out:
#                 text       group
# count           2447        3000
# unique          2429           5
# top     Доброе утро!  krishnaits
# freq               5         600

# %%
import nltk
import re
from pymystem3 import Mystem

nltk.download('punkt')
mystem_analyzer = Mystem()

lemmatized = []
unlemmatized = []

for doc in df['text']:
    text = re.sub("<br>", "", str(doc))
    word_list = nltk.word_tokenize(text)
    unlemmatized.append(word_list)
    lemmatized.append([mystem_analyzer.lemmatize(word)[0] for word in word_list])
# Out:
# [nltk_data] Downloading package punkt to /home/valeria/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from itertools import chain

count_unlem = 0

for el in unlemmatized:
    count_unlem += len(el)

cont_lemmatized = list(chain.from_iterable(lemmatized))

print("Количество токенов в датасете:", count_unlem)
print("Количество уникальных лемм:", len(set(cont_lemmatized)))
# Out:
# Количество токенов в датасете: 1080243
# Количество уникальных лемм: 44

# %%
words_per_doc = np.mean([len(text) for text in unlemmatized])
symbols_per_doc = np.mean([len(str(doc)) for doc in df["text"]])

print("Среднее количество слов на документ:", int(words_per_doc))
print("Среднее количество символов на документ:", int(symbols_per_doc))
# Out:
# Среднее количество слов на документ: 360
# Среднее количество символов на документ: 1336

# %%
from nltk.corpus import stopwords
import pymorphy2 as pm2

pmm = pm2.MorphAnalyzer()
russian_stopwords = stopwords.words("russian")

# сюда добавить парсинг получше
def parse(text):
    text = re.sub(r'[^\w\s]','', str(text))
    text = re.sub("[0-9A-Za-z#_]", "", text)
    text = [pmm.normal_forms(x)[0] for x in text.split() if x not in russian_stopwords]
    if text == [np.nan]:
        return(['nan'])
    return text

df['text'] = df['text'].apply(parse)
df["text"]
# Out:
# id
# 1949    [таинственный, место, россия, церковь, весь, с...
# 159     [забавно, москва, самый, крупный, белый, город...
# 675                                                    []
# 2847    [куд, допомочь, утро, шизосель, снова, взойти,...
# 446     [повесть, временной, год, известно, основа, ру...
# 551     [ватник, рррррять, ветеран, накаточный, дед, п...
# 2702    [куд, бой, тень, куд, патрулировать, двор, нал...
# 109     [сказать, чрезмерный, жара, подрывать, сила, б...
# 879     [харинама, город, говардхан, картик, парикра, ...
# 2507    [куд, телефонный, пранкер, безопасный, достава...
# 2574    [куд, мастер, разговор, гопник, кудахома, идти...
# 2943    [куд, лолифоксер, куд, пидарнуль, двач, вера, ...
# 2826    [куд, трактор, давать, тянуть, никакой, сокров...
# 539     [санктпетербург, озёрный, переулок, далее, мес...
# 1368    [кгда, спршивать, отвчаять, птом, весь, день, ...
# 2502    [куд, зелень, весь, зелёный, весной, куд, это,...
# 997     [приглашать, парикра, ツ, вриндаван, хара, криш...
# 2303                                    [контакт, плеяда]
# 2379                                                   []
# 1325                      [желать, счастие, свет, душить]
# 2608    [куд, шизосель, весь, порядок, куд, клевать, г...
# 2964    [куд, сесть, сесть, куд, надоесть, стоять, сво...
# 2335    [апрель, год, примерно, местный, время, неизве...
# 738                                                    []
# 1550                                   [полезный, рецепт]
# 431     [братец, очень, важный, вопрос, особенно, нужн...
# 2518    [виликия, совет, помочь, куд, куд, очень, плох...
# 639     [варшан, место, бог, танцевать, дать, гарх, ка...
# 2074                                                   []
# 1461                                                   []
#                               ...
# 680                                                    []
# 2792    [куд, сраный, пила, куд, дед, чинить, бензопил...
# 1914                                                   []
# 993     [семинар, картик, месяц, шримати, радхарань, р...
# 1167                                                   []
# 595     [примета, последний, время, кудато, ехать, рол...
# 1057    [прошлое, жизнь, предать, шб, сандхьяаватар, д...
# 773     [новый, книга, шри, югадхарма, санга, хара, кр...
# 777     [правильный, отношение, житель, варшан, картик...
# 1879     [факт, существование, инопланетянин, обзор, нло]
# 220     [впутин, зачастить, старообрядец, поповский, с...
# 2569    [кудахи, дебил, куд, уверенный, коричневый, ку...
# 2908    [заниматься, ваш, куд, курятник, видеть, куд, ...
# 711                                                    []
# 638                     [известный, вегана, вегетарианец]
# 1843    [добрый, время, сутки, май, год, минута, видет...
# 444     [дорогой, братец, сестричка, приглашать, октяб...
# 358     [лёт, самый, дело, это, навсегда, пройти, сто,...
# 2869    [куд, чёрточка, сегодня, куд, хороший, день, к...
# 303     [сила, волга, пожалуй, сказать, волга, русский...
# 1432    [это, роскошь, вечный, желание, получить, это,...
# 2644    [куд, ночной, пора, вставать, подойти, собака,...
# 766                                                    []
# 122     [пройти, лес, знакомый, поворот, видеть, просв...
# 2832    [куд, криогеника, куд, узнать, человек, заморо...
# 2249                                   [галактика, хвост]
# 1107    [подготовить, встреча, кришна, каждый, день, с...
# 2175                      [незнание, приводить, фантазия]
# 40      [читать, последний, предложение, стоить, несмо...
# 2197    [здравствовать, случайно, сделать, фотка, кото...
# Name: text, Length: 3000, dtype: object

# %%
# for idx, row in df.iterrows():
#     if row['text'] == []:
#         df = df.drop(index=idx)
df
# Out:
#                                                    text       group
# id
# 1949  [таинственный, место, россия, церковь, весь, с...         ufo
# 159   [забавно, москва, самый, крупный, белый, город...    podkoren
# 675                                                  []  krishnaits
# 2847  [куд, допомочь, утро, шизосель, снова, взойти,...       kudah
# 446   [повесть, временной, год, известно, основа, ру...    podkoren
# 551   [ватник, рррррять, ветеран, накаточный, дед, п...    podkoren
# 2702  [куд, бой, тень, куд, патрулировать, двор, нал...       kudah
# 109   [сказать, чрезмерный, жара, подрывать, сила, б...    podkoren
# 879   [харинама, город, говардхан, картик, парикра, ...  krishnaits
# 2507  [куд, телефонный, пранкер, безопасный, достава...       kudah
# 2574  [куд, мастер, разговор, гопник, кудахома, идти...       kudah
# 2943  [куд, лолифоксер, куд, пидарнуль, двач, вера, ...       kudah
# 2826  [куд, трактор, давать, тянуть, никакой, сокров...       kudah
# 539   [санктпетербург, озёрный, переулок, далее, мес...    podkoren
# 1368  [кгда, спршивать, отвчаять, птом, весь, день, ...    telegony
# 2502  [куд, зелень, весь, зелёный, весной, куд, это,...       kudah
# 997   [приглашать, парикра, ツ, вриндаван, хара, криш...  krishnaits
# 2303                                  [контакт, плеяда]         ufo
# 2379                                                 []         ufo
# 1325                    [желать, счастие, свет, душить]    telegony
# 2608  [куд, шизосель, весь, порядок, куд, клевать, г...       kudah
# 2964  [куд, сесть, сесть, куд, надоесть, стоять, сво...       kudah
# 2335  [апрель, год, примерно, местный, время, неизве...         ufo
# 738                                                  []  krishnaits
# 1550                                 [полезный, рецепт]    telegony
# 431   [братец, очень, важный, вопрос, особенно, нужн...    podkoren
# 2518  [виликия, совет, помочь, куд, куд, очень, плох...       kudah
# 639   [варшан, место, бог, танцевать, дать, гарх, ка...  krishnaits
# 2074                                                 []         ufo
# 1461                                                 []    telegony
# ...                                                 ...         ...
# 680                                                  []  krishnaits
# 2792  [куд, сраный, пила, куд, дед, чинить, бензопил...       kudah
# 1914                                                 []         ufo
# 993   [семинар, картик, месяц, шримати, радхарань, р...  krishnaits
# 1167                                                 []  krishnaits
# 595   [примета, последний, время, кудато, ехать, рол...    podkoren
# 1057  [прошлое, жизнь, предать, шб, сандхьяаватар, д...  krishnaits
# 773   [новый, книга, шри, югадхарма, санга, хара, кр...  krishnaits
# 777   [правильный, отношение, житель, варшан, картик...  krishnaits
# 1879   [факт, существование, инопланетянин, обзор, нло]         ufo
# 220   [впутин, зачастить, старообрядец, поповский, с...    podkoren
# 2569  [кудахи, дебил, куд, уверенный, коричневый, ку...       kudah
# 2908  [заниматься, ваш, куд, курятник, видеть, куд, ...       kudah
# 711                                                  []  krishnaits
# 638                   [известный, вегана, вегетарианец]  krishnaits
# 1843  [добрый, время, сутки, май, год, минута, видет...         ufo
# 444   [дорогой, братец, сестричка, приглашать, октяб...    podkoren
# 358   [лёт, самый, дело, это, навсегда, пройти, сто,...    podkoren
# 2869  [куд, чёрточка, сегодня, куд, хороший, день, к...       kudah
# 303   [сила, волга, пожалуй, сказать, волга, русский...    podkoren
# 1432  [это, роскошь, вечный, желание, получить, это,...    telegony
# 2644  [куд, ночной, пора, вставать, подойти, собака,...       kudah
# 766                                                  []  krishnaits
# 122   [пройти, лес, знакомый, поворот, видеть, просв...    podkoren
# 2832  [куд, криогеника, куд, узнать, человек, заморо...       kudah
# 2249                                 [галактика, хвост]         ufo
# 1107  [подготовить, встреча, кришна, каждый, день, с...  krishnaits
# 2175                    [незнание, приводить, фантазия]         ufo
# 40    [читать, последний, предложение, стоить, несмо...    podkoren
# 2197  [здравствовать, случайно, сделать, фотка, кото...         ufo
#
# [3000 rows x 2 columns]

# %%
df = df.reindex(index=range(len(df)))
cross_val_folds = []

fold = []

for idx, row in df.iterrows():
    fold.append(row)
    if idx % (len(df) // 10) == 0:
        cross_val_folds.append(fold)
        fold = []

len(cross_val_folds)
# Out:
# 10

# %%
cross_val_folds = cross_val_folds[1:]

for fold in cross_val_folds:
    print(len(fold))
# Out:
# 300
# 300
# 300
# 300
# 300
# 300
# 300
# 300
# 300

# %% [markdown]
# ## TF-IDF

# %%
from gensim.models import TfidfModel
from gensim.corpora import Dictionary

dct = Dictionary()
#for text in lemmatized_corpus:
dct.add_documents(df["text"])
corpus = []
for idx, row in df.iterrows():
    corpus.append(dct.doc2bow(row['text']))
idfs = {}
tf_idf = TfidfModel(corpus)
for key in dct:
    try:
        idfs[dct[key]] = tf_idf.idfs[key]
    except KeyError:
        pass

# %%
vector = tf_idf[corpus[0][:10]]
vector
# Out:
# [(0, 0.36221007863501486),
#  (1, 0.1467250140965477),
#  (2, 0.41541282888806597),
#  (3, 0.42624121900071205),
#  (4, 0.26131078311247774),
#  (5, 0.3324372938635929),
#  (6, 0.35322561348812204),
#  (7, 0.2531146050432289),
#  (8, 0.24608396493680115),
#  (9, 0.2546285513490461)]

# %% [markdown]
# ## Embeddings

# %%
from gensim.models import Word2Vec

model = Word2Vec.load("full.model")

# %% [markdown]
# ## Sentence split

# %%
df_split = pd.read_csv('data.csv', index_col='id')
df_split = df_split.sample(frac=1)

def sent_split(text):
    sents = nltk.sent_tokenize(str(text))
    return sents

df_split['text'] = df_split['text'].apply(sent_split)
df_split["text"][20]
# Out:
# ['Показательная фотокарточка.',
#  'Бойцы «IFB» (интернациональный левый «батальон» в составе курдских «SDF») вывесили над Раккой, бывшей столицей Исламского Государства, красный советский флаг.',
#  'Мол, советские войска спасли мир от фашизма, освободив Берлин, а мы, продолжатели левого дела, спасли мир от «ИГ».',
#  'Несоответствие в том, что, по правде говоря, вывешивать над Раккой надо было американский флаг, ибо американская авиация, артиллерия, бронетехника, пехота как раз и обеспечили курдам их «левую» победу.',
#  'Вплоть до бомбёжек со стратегов B-1 и того, что американский спецназ гонял с шевронами антикапиталистической «YPG».',
#  'Без этой помощи курдов добили бы ещё в Кобани осенью 2014 года.',
#  'Но левых пользователей из «IFB» не смущает колоссальная поддержка мощнейшей капиталистической страны, которая в ХХ веке делала всё возможное, чтобы уничтожить «социалистические» государства и движения.',
#  'Главное, что у нас есть красный флаг.',
#  'Как-то так и выглядит состояние послемодерна: картинка важнее смысла; повторение воспроизводит форму, а не ситуацию; символ становится содержанием; немногочисленная группка разрастается в целый батальон.',
#  'А в мире всё остаётся по-прежнему.',
#  '#ПК_мысли']
